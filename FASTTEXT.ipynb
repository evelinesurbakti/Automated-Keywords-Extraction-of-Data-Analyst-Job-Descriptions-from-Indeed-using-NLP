# %% [markdown]
# <a href="https://colab.research.google.com/github/evelinesurbakti/Automated-Keywords-Extraction-of-Data-Analyst-Job-Descriptions-from-Indeed-using-NLP/blob/main/FASTTEXT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#! pip install fasttext
# Out:
# ...
# ERROR: Operation cancelled by user

# %%
import fasttext.util
fasttext.util.download_model('en', if_exists='ignore')  # English
ft = fasttext.load_model('cc.en.300.bin')

# %%
import pandas as pd
import numpy as np
import scipy as sp
import panda

# %%
NumPy & SciPy and pybind11.

# %%
df = pd.read_csv("Zoomd_Clean.csv")

# %%
df
# Out:
#                                   Accountid  ...   Zoom
# 0      af6778ec-65c1-46ed-a443-d0534ce71088  ...  100.0
# 1      c927821b-720a-4edc-8f6b-06b4c21c99ef  ...  100.0
# 2      0331827d-74e3-436c-b406-7214f4b29796  ...  100.0
# 3      cbc2d52a-a25b-417a-8654-538601da089c  ...   99.0
# 4      d29194be-f510-4062-a937-aee619eec8a8  ...   98.0
# ...                                     ...  ...    ...
# 19995  388c96a0-6ccd-4ae3-b260-aca6c2d06cb9  ...    NaN
# 19996  58b2219a-6016-4601-a087-d0c157a69b55  ...   22.0
# 19997  a7bbcd08-49dc-4648-b3c3-8462f8953404  ...  100.0
# 19998  388c96a0-6ccd-4ae3-b260-aca6c2d06cb9  ...  100.0
# 19999  c927821b-720a-4edc-8f6b-06b4c21c99ef  ...  100.0
#
# [20000 rows x 28 columns]

# %%
ft.get_dimension()
# Out:
# 300

# %%
fasttext.util.reduce_model(ft, 100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-77a6771dc63a> in <module>()
# ----> 1 fasttext.util.reduce_model(ft, 100)
#
# NameError: name 'fasttext' is not defined
